# %% [markdown]
# # Subway Station Game
#
# ---
#
# Creator : YHC03
#
# 주요 알고리즘 작성일 : 2022.10.22
# 역 목록 최초 작성일 : 2022.10.21
# 역 목록 수정일 : 2024.05.13
# 역 목록 작성기준일 : 2024.04.28

# %% [markdown]
# ### 1. Subway Line List

# %%
Lines=[]

# %%
Lines.append("서울 1호선") # 0
Lines.append("서울 2호선") # 1
Lines.append("서울 3호선") # 2
Lines.append("서울 4호선") # 3
Lines.append("서울 5호선") # 4
Lines.append("서울 6호선") # 5
Lines.append("서울 7호선") # 6
Lines.append("서울 8호선") # 7
Lines.append("서울 9호선") # 8
Lines.append("인천 1호선") # 9
Lines.append("인천 2호선") # 10
Lines.append("공항철도") # 11
Lines.append("경의.중앙선") # 12
Lines.append("수인.분당선") # 13
Lines.append("우이신설선") # 14
Lines.append("신분당선") # 15
Lines.append("에버라인") # 16
Lines.append("의정부경전철") # 17
Lines.append("김포골드라인") # 18
Lines.append("신림선") # 19
Lines.append("경춘선") # 20
Lines.append("경강선") # 21
Lines.append("서해선") # 22
Lines.append("GTX-A") # 23
# 자기부상열차 미반영

# %% [markdown]
# ### 2. Station Management Variable

# %%
All_Stations=[]

# %%
#StationName 중복 처리 안함(양평역 중복 문제)
def AppendStation(stationName="미개통", lines=[]):
    All_Stations.append([stationName, lines, 0])

# %% [markdown]
# 역 입력(노선번호 순. 동일 역은 한번만 기입. 단, 양평역은 다른 역임.)
#
# Enter Stations(Sorted by Line Number. Same stations are entered only once, however, Yangpyeong Station is not the same station.)

# %%
# 1호선(연천-구로 간)
AppendStation("연천", [0])
AppendStation("전곡", [0])
AppendStation("청산", [0])
AppendStation("소요산", [0])
AppendStation("동두천", [0])
AppendStation("동두천중앙", [0])
AppendStation("보산", [0])
AppendStation("지행", [0])
AppendStation("덕정", [0])
AppendStation("덕계", [0])
AppendStation("양주", [0])
AppendStation("녹양", [0])
AppendStation("가능", [0])
AppendStation("의정부", [0])
AppendStation("회룡", [0, 17])
AppendStation("망월사", [0])
AppendStation("도봉산", [0, 6])
AppendStation("도봉", [0])
AppendStation("방학", [0])
AppendStation("창동", [0, 3])
AppendStation("녹천", [0])
AppendStation("월계", [0])
AppendStation("광운대", [0, 20])
AppendStation("석계", [0, 5])
AppendStation("신이문", [0])
AppendStation("외대앞", [0])
AppendStation("회기", [0, 12, 20])
AppendStation("청량리", [0, 12, 13, 20])
AppendStation("제기동", [0])
AppendStation("신설동", [0, 1, 14])
AppendStation("동묘앞", [0, 5])
AppendStation("동대문", [0, 3])
AppendStation("종로5가", [0])
AppendStation("종로3가", [0, 2, 4])
AppendStation("종각", [0])
AppendStation("시청", [0, 1])
AppendStation("서울역", [0, 3, 11, 12]) # 23 GTX-A 개통예정
AppendStation("남영", [0])
AppendStation("용산", [0, 12])
AppendStation("노량진", [0, 8])
AppendStation("대방", [0, 19])
AppendStation("신길", [0, 4])
AppendStation("영등포", [0])
AppendStation("신도림", [0, 1])
AppendStation("구로", [0])

# 1호선(구일-인천 간)
AppendStation("구일", [0])
AppendStation("개봉", [0])
AppendStation("오류동", [0])
AppendStation("온수", [0, 6])
AppendStation("역곡", [0])
AppendStation("소사", [0, 22])
AppendStation("부천", [0])
AppendStation("중동", [0])
AppendStation("송내", [0])
AppendStation("부평", [0, 9])
AppendStation("백운", [0])
AppendStation("동암", [0])
AppendStation("간석", [0])
AppendStation("주안", [0, 10])
AppendStation("도화", [0])
AppendStation("제물포", [0])
AppendStation("도원", [0])
AppendStation("동인천", [0])
AppendStation("인천", [0, 13])

# 1호선(가리봉-신창 간)
AppendStation("가산디지털단지", [0, 6])
AppendStation("독산", [0])
AppendStation("금천구청", [0])
AppendStation("광명", [0])
AppendStation("석수", [0])
AppendStation("관악", [0])
AppendStation("안양", [0])
AppendStation("명학", [0])
AppendStation("금정", [0, 3])
AppendStation("군포", [0])
AppendStation("당정", [0])
AppendStation("의왕", [0])
AppendStation("성균관대", [0])
AppendStation("화서", [0])
AppendStation("수원", [0, 13])
AppendStation("세류", [0])
AppendStation("병점", [0])
AppendStation("서동탄", [0])
AppendStation("세마", [0])
AppendStation("오산대", [0])
AppendStation("오산", [0])
AppendStation("진위", [0])
AppendStation("송탄", [0])
AppendStation("서정리", [0])
AppendStation("평택지제", [0])
AppendStation("평택", [0])
AppendStation("성환", [0])
AppendStation("직산", [0])
AppendStation("두정", [0])
AppendStation("천안", [0])
AppendStation("봉명", [0])
AppendStation("쌍용", [0])
AppendStation("아산", [0])
AppendStation("탕정", [0])
AppendStation("배방", [0])
# AppendStation("풍기", [0]) # 미개통
AppendStation("온양온천", [0])
AppendStation("신창", [0])

# 2호선(순환선)
AppendStation("을지로입구", [1])
AppendStation("을지로3가", [1, 2])
AppendStation("을지로4가", [1, 4])
AppendStation("동대문역사문화공원", [1, 3, 4])
AppendStation("신당", [1, 5])
AppendStation("상왕십리", [1])
AppendStation("왕십리", [1, 4, 12, 13])
AppendStation("한양대", [1])
AppendStation("뚝섬", [1])
AppendStation("성수", [1])
AppendStation("건대입구", [1, 6])
AppendStation("구의", [1])
AppendStation("강변", [1])
AppendStation("잠실나루", [1])
AppendStation("잠실", [1, 7])
AppendStation("잠실새내", [1])
AppendStation("종합운동장", [1, 8])
AppendStation("삼성", [1]) # 23 GTX-A 개통예정
AppendStation("선릉", [1, 13])
AppendStation("역삼", [1])
AppendStation("강남", [1, 15])
AppendStation("교대", [1, 2])
AppendStation("서초", [1])
AppendStation("방배", [1])
AppendStation("사당", [1, 3])
AppendStation("낙성대", [1])
AppendStation("서울대입구", [1])
AppendStation("봉천", [1])
AppendStation("신림", [1, 19])
AppendStation("신대방", [1])
AppendStation("구로디지털단지", [1])
AppendStation("대림", [1, 6])
AppendStation("문래", [1])
AppendStation("영등포구청", [1, 4])
AppendStation("당산", [1, 8])
AppendStation("합정", [1, 5])
AppendStation("홍대입구", [1, 11, 12])
AppendStation("신촌", [1]) # 경의선 신촌역과 다른 역
AppendStation("이대", [1])
AppendStation("아현", [1])
AppendStation("충정로", [1, 4])

#2호선(신정지선)
AppendStation("도림천", [1])
AppendStation("양천구청", [1])
AppendStation("신정네거리", [1])
AppendStation("까치산", [1, 4])

#2호선(성수지선)
AppendStation("용답", [1])
AppendStation("신답", [1])
AppendStation("용두", [1])

#3호선
AppendStation("대화", [2])
AppendStation("주엽", [2])
AppendStation("정발산", [2])
AppendStation("마두", [2])
AppendStation("백석", [2])
AppendStation("대곡", [2, 12, 22]) # 23 GTX-A 개통예정
AppendStation("화정", [2])
AppendStation("원당", [2])
AppendStation("원흥", [2])
AppendStation("삼송", [2])
AppendStation("지축", [2])
AppendStation("구파발", [2])
AppendStation("연신내", [2, 5]) # 23 GTX-A 개통예정
AppendStation("불광", [2, 5])
AppendStation("녹번", [2])
AppendStation("홍제", [2])
AppendStation("무악재", [2])
AppendStation("독립문", [2])
AppendStation("경복궁", [2])
AppendStation("안국", [2])
AppendStation("충무로", [2, 3])
AppendStation("동대입구", [2])
AppendStation("약수", [2, 5])
AppendStation("금호", [2])
AppendStation("옥수", [2, 12])
AppendStation("압구정", [2])
AppendStation("신사", [2, 15])
AppendStation("잠원", [2])
AppendStation("고속터미널", [2, 6, 8])
AppendStation("남부터미널", [2])
AppendStation("양재", [2, 15])
AppendStation("매봉", [2])
AppendStation("도곡", [2, 13])
AppendStation("대치", [2])
AppendStation("학여울", [2])
AppendStation("대청", [2])
AppendStation("일원", [2])
AppendStation("수서", [2, 13, 23])
AppendStation("가락시장", [2, 7])
AppendStation("경찰병원", [2])
AppendStation("오금", [2, 4])

#4호선
AppendStation("진접", [3])
AppendStation("오남", [3])
#AppendStation("풍양", [3]) # 미개통
AppendStation("별내별가람", [3])
AppendStation("당고개", [3])
AppendStation("상계", [3])
AppendStation("노원", [3, 6])
AppendStation("쌍문", [3])
AppendStation("수유", [3])
AppendStation("미아", [3])
AppendStation("미아사거리", [3])
AppendStation("길음", [3])
AppendStation("성신여대입구", [3, 14])
AppendStation("한성대입구", [3])
AppendStation("혜화", [3])
AppendStation("명동", [3])
AppendStation("회현", [3])
AppendStation("숙대입구", [3])
AppendStation("삼각지", [3, 5])
AppendStation("신용산", [3])
AppendStation("이촌", [3, 12])
AppendStation("동작", [3, 8])
AppendStation("이수", [3, 6])
AppendStation("남태령", [3])
AppendStation("선바위", [3])
AppendStation("경마공원", [3])
AppendStation("대공원", [3])
AppendStation("과천", [3])
AppendStation("정부과천청사", [3])
AppendStation("인덕원", [3])
AppendStation("평촌", [3])
AppendStation("범계", [3])
AppendStation("산본", [3])
AppendStation("수리산", [3])
AppendStation("대야미", [3])
AppendStation("반월", [3])
AppendStation("상록수", [3])
AppendStation("한대앞", [3, 13])
AppendStation("중앙", [3, 13])
AppendStation("고잔", [3, 13])
AppendStation("초지", [3, 13, 22])
AppendStation("안산", [3, 13])
AppendStation("신길온천", [3, 13])
AppendStation("정왕", [3, 13])
AppendStation("오이도", [3, 13])

#5호선(본선)
AppendStation("방화", [4])
AppendStation("개화산", [4])
AppendStation("김포공항", [4, 8, 11, 18, 22])
AppendStation("송정", [4])
AppendStation("마곡", [4])
AppendStation("발산", [4])
AppendStation("우장산", [4])
AppendStation("화곡", [4])
AppendStation("신정", [4])
AppendStation("목동", [4])
AppendStation("오목교", [4])
AppendStation("양평", [4]) # 경의.중앙선 양평역과 다른 역
AppendStation("영등포시장", [4])
AppendStation("여의도", [4, 8])
AppendStation("여의나루", [4])
AppendStation("마포", [4])
AppendStation("공덕", [4, 5, 11, 12])
AppendStation("애오개", [4])
AppendStation("서대문", [4])
AppendStation("광화문", [4])
AppendStation("청구", [4, 5])
AppendStation("신금호", [4])
AppendStation("행당", [4])
AppendStation("마장", [4])
AppendStation("답십리", [4])
AppendStation("장한평", [4])
AppendStation("군자", [4, 5])
AppendStation("아차산", [4])
AppendStation("광나루", [4])
AppendStation("천호", [4, 7])
AppendStation("강동", [4])
AppendStation("길동", [4])
AppendStation("굽은다리", [4])
AppendStation("명일", [4])
AppendStation("고덕", [4])
AppendStation("상일동", [4])
AppendStation("강일", [4])
AppendStation("미사", [4])
AppendStation("하남풍산", [4])
AppendStation("하남시청", [4])
AppendStation("하남검단산", [4])

#5호선(마천지선)
AppendStation("둔촌동", [4])
AppendStation("올림픽공원", [4, 8])
AppendStation("방이", [4])
AppendStation("개롱", [4])
AppendStation("거여", [4])
AppendStation("마천", [4])

#6호선
AppendStation("신내", [5, 20])
AppendStation("봉화산", [5])
AppendStation("화랑대", [5])
AppendStation("태릉입구", [5, 6])
AppendStation("돌곶이", [5])
AppendStation("상월곡", [5])
AppendStation("월곡", [5])
AppendStation("고려대", [5])
AppendStation("안암", [5])
AppendStation("보문", [5, 14])
AppendStation("창신", [5])
AppendStation("버티고개", [5])
AppendStation("한강진", [5])
AppendStation("이태원", [5])
AppendStation("녹사평", [5])
AppendStation("효창공원앞", [5, 12])
AppendStation("대흥", [5])
AppendStation("광흥창", [5])
AppendStation("상수", [5])
AppendStation("합정", [5])
AppendStation("망원", [5])
AppendStation("마포구청", [5])
AppendStation("월드컵경기장", [5])
AppendStation("디지털미디어시티", [5, 11, 12])
AppendStation("증산", [5])
AppendStation("새절", [5])
AppendStation("응암", [5])
AppendStation("역촌", [5])
AppendStation("독바위", [5])
AppendStation("구산", [5])

#7호선
AppendStation("장암", [6])
AppendStation("수락산", [6])
AppendStation("마들", [6])
AppendStation("중계", [6])
AppendStation("하계", [6])
AppendStation("공릉", [6])
AppendStation("먹골", [6])
AppendStation("중화", [6])
AppendStation("상봉", [6, 12, 20])
AppendStation("면목", [6])
AppendStation("사가정", [6])
AppendStation("용마산", [6])
AppendStation("중곡", [6])
AppendStation("어린이대공원", [6])
AppendStation("자양", [6])
AppendStation("청담", [6])
AppendStation("강남구청", [6, 13])
AppendStation("학동", [6])
AppendStation("논현", [6, 15])
AppendStation("반포", [6])
AppendStation("내방", [6])
AppendStation("남성", [6])
AppendStation("숭실대입구", [6])
AppendStation("상도", [6])
AppendStation("장승배기", [6])
AppendStation("신대방삼거리", [6])
AppendStation("보라매", [6, 19])
AppendStation("신풍", [6])
AppendStation("남구로", [6])
AppendStation("철산", [6])
AppendStation("광명사거리", [6])
AppendStation("천왕", [6])
AppendStation("까치울", [6])
AppendStation("부천종합운동장", [6])
AppendStation("춘의", [6])
AppendStation("신중동", [6])
AppendStation("부천시청", [6])
AppendStation("상동", [6])
AppendStation("삼산체육관", [6])
AppendStation("굴포천", [6])
AppendStation("부평구청", [6, 9])
AppendStation("산곡", [6])
AppendStation("석남", [6, 10])

#8호선
AppendStation("암사", [7])
AppendStation("강동구청", [7])
AppendStation("뭉촌토성", [7])
AppendStation("석촌", [7, 8])
AppendStation("송파", [7])
AppendStation("문정", [7])
AppendStation("장지", [7])
AppendStation("복정", [7, 13])
AppendStation("남위례", [7])
AppendStation("산성", [7])
AppendStation("남한산성입구", [7])
AppendStation("단대오거리", [7])
AppendStation("신흥", [7])
AppendStation("수진", [7])
AppendStation("모란", [7, 13])

#9호선
AppendStation("개화", [8])
AppendStation("공항시장", [8])
AppendStation("신방화", [8])
AppendStation("마곡나루", [8, 11])
AppendStation("양천향교", [8])
AppendStation("가양", [8])
AppendStation("증미", [8])
AppendStation("염창", [8])
AppendStation("신목동", [8])
AppendStation("선유도", [8])
AppendStation("국회의사당", [8])
AppendStation("샛강", [8, 19])
AppendStation("노들", [8])
AppendStation("흑석", [8])
AppendStation("구반포", [8])
AppendStation("신반포", [8])
AppendStation("사평", [8])
AppendStation("언주", [8])
AppendStation("선정릉", [8, 13])
AppendStation("삼성중앙", [8])
AppendStation("봉은사", [8])
AppendStation("삼전", [8])
AppendStation("석촌고분", [8])
AppendStation("송파나루", [8])
AppendStation("한성백제", [8])
AppendStation("둔촌오륜", [8])
AppendStation("중앙보훈병원", [8])

#인천 1호선
AppendStation("계양", [9, 11])
AppendStation("귤현", [9])
AppendStation("박촌", [9])
AppendStation("임학", [9])
AppendStation("계산", [9])
AppendStation("경인교대입구", [9])
AppendStation("작전", [9])
AppendStation("갈산", [9])
AppendStation("부평시장", [9])
AppendStation("동수", [9])
AppendStation("부평오거리", [9])
AppendStation("간석오거리", [9])
AppendStation("인천시청", [9, 10])
AppendStation("예술회관", [9])
AppendStation("인천터미널", [9])
AppendStation("문학경기장", [9])
AppendStation("선학", [9])
AppendStation("신연수", [9])
AppendStation("원인재", [9, 13])
AppendStation("동춘", [9])
AppendStation("동막", [9])
AppendStation("캠퍼스타운", [9])
AppendStation("테크노파크", [9])
AppendStation("지식정보단지", [9])
AppendStation("인천대입구", [9])
AppendStation("센트럴파크", [9])
AppendStation("국제업무지구", [9])
AppendStation("송도달빛축제공원", [9])

#인천 2호선
AppendStation("검단오류", [10])
AppendStation("왕길", [10])
AppendStation("검단사거리", [10])
AppendStation("마전", [10])
AppendStation("완정", [10])
AppendStation("독정", [10])
AppendStation("검암", [10, 11])
AppendStation("검바위", [10])
AppendStation("아시아드경기장", [10])
AppendStation("서구청", [10])
AppendStation("가정", [10])
AppendStation("가정중앙시장", [10])
AppendStation("서부여성회관", [10])
AppendStation("인천가좌", [10])
AppendStation("가재울", [10])
AppendStation("주안국가산단", [10])
AppendStation("시민공원", [10])
AppendStation("석바위시장", [10])
AppendStation("석천사거리", [10])
AppendStation("모래내시장", [10])
AppendStation("만수", [10])
AppendStation("남동구청", [10])
AppendStation("인천대공원", [10])
AppendStation("운연", [10])

#공항철도
AppendStation("청라국제도시", [11])
AppendStation("영종", [11])
AppendStation("운서", [11])
AppendStation("공항화물청사", [11])
AppendStation("인천공항1터미널", [11])
AppendStation("인천공항2터미널", [11])
#AppendStation("용유", [11]) # 현재 운행 안함

#경의.중앙선(경의선)
#AppendStation("도라산", [12]) # 지하철이라 보기 애매함
AppendStation("임진강", [12])
AppendStation("운천", [12])
AppendStation("문산", [12])
AppendStation("파주", [12])
AppendStation("월롱", [12])
AppendStation("금촌", [12])
AppendStation("금릉", [12])
AppendStation("운정", [12])
AppendStation("야당", [12])
AppendStation("탄현", [12])
AppendStation("일산", [12, 22])
AppendStation("풍산", [12, 22])
AppendStation("백마", [12, 22])
AppendStation("곡산", [12, 22])
AppendStation("능곡", [12, 22])
AppendStation("행신", [12])
AppendStation("강매", [12])
AppendStation("한국항공대", [12])
AppendStation("수색", [12])
AppendStation("가좌", [12])
AppendStation("신촌", [12]) # 2호선과 다른 역

#경의.중앙선(용산선)
AppendStation("서강대", [12])

#경의.중앙선(경원선+중앙선)
AppendStation("서빙고", [12])
AppendStation("한남", [12])
AppendStation("응봉", [12])
AppendStation("중랑", [12, 20])
AppendStation("망우", [12, 20])
AppendStation("양원", [12])
AppendStation("구리", [12])
AppendStation("도농", [12])
AppendStation("양정", [12])
AppendStation("덕소", [12])
AppendStation("도심", [12])
AppendStation("팔당", [12])
AppendStation("운길산", [12])
AppendStation("양수", [12])
AppendStation("신원", [12])
AppendStation("국수", [12])
AppendStation("아신", [12])
AppendStation("오빈", [12])
AppendStation("양평", [12]) # 5호선 양평역과 다른 역
AppendStation("원덕", [12])
AppendStation("용문", [12])
AppendStation("지평", [12])

#수인.분당선
AppendStation("서울숲", [13])
AppendStation("압구정로데오", [13])
AppendStation("한티", [13])
AppendStation("구룡", [13])
AppendStation("개포동", [13])
AppendStation("대모산입구", [13])
AppendStation("가천대", [13])
AppendStation("태평", [13])
AppendStation("야탑", [13])
AppendStation("이매", [13, 21])
AppendStation("서현", [13])
AppendStation("수내", [13])
AppendStation("정자", [13, 15])
AppendStation("미금", [13, 15])
AppendStation("오리", [13])
AppendStation("죽전", [13])
AppendStation("보정", [13])
AppendStation("구성", [13]) # 23 GTX-A 개통예정
AppendStation("신갈", [13])
AppendStation("기흥", [13, 16])
AppendStation("상갈", [13])
AppendStation("청명", [13])
AppendStation("영통", [13])
AppendStation("망포", [13])
AppendStation("매탄권선", [13])
AppendStation("수원시청", [13])
AppendStation("매교", [13])
AppendStation("고색", [13])
AppendStation("오목천", [13])
AppendStation("어천", [13])
AppendStation("야목", [13])
AppendStation("사리", [13])
AppendStation("달월", [13])
AppendStation("월곶", [13])
AppendStation("소래포구", [13])
AppendStation("인천논현", [13])
AppendStation("호구포", [13])
AppendStation("남동인더스파크", [13])
AppendStation("연수", [13])
AppendStation("송도", [13])
AppendStation("인하대", [13])
AppendStation("숭의", [13])
AppendStation("신포", [13])

#우이신설선
AppendStation("정릉", [14])
AppendStation("북한산보국문", [14])
AppendStation("솔샘", [14])
AppendStation("삼양사거리", [14])
AppendStation("삼양", [14])
AppendStation("화계", [14])
AppendStation("가오리", [14])
AppendStation("4.19민주묘지", [14])
AppendStation("솔밭공원", [14])
AppendStation("북한산우이", [14])

#신분당선
AppendStation("양재시민의숲", [15])
AppendStation("청계산입구", [15])
AppendStation("판교", [15, 21])
AppendStation("동천", [15])
AppendStation("수지구청", [15])
AppendStation("성복", [15])
AppendStation("상현", [15])
AppendStation("광교중앙", [15])
AppendStation("광교", [15])

#에버라인
AppendStation("강남대", [16])
AppendStation("지석", [16])
AppendStation("어정", [16])
AppendStation("동백", [16])
AppendStation("초당", [16])
AppendStation("삼가", [16])
AppendStation("시청.용인대", [16])
AppendStation("명지대", [16])
AppendStation("김량장", [16])
AppendStation("용인중앙시장", [16])
AppendStation("고진", [16])
AppendStation("보평", [16])
AppendStation("둔전", [16])
AppendStation("전대.에버랜드", [16])

#의정부경전철
AppendStation("발곡", [17])
AppendStation("범골", [17])
AppendStation("경전철의정부", [17])
AppendStation("의정부시청", [17])
AppendStation("흥선", [17])
AppendStation("의정부중앙", [17])
AppendStation("동오", [17])
AppendStation("새말", [17])
AppendStation("경기도청북부청사", [17])
AppendStation("효자", [17])
AppendStation("곤제", [17])
AppendStation("어룡", [17])
AppendStation("송산", [17])
AppendStation("탑석", [17])

#김포골드라인
AppendStation("양촌", [18])
AppendStation("구래", [18])
AppendStation("마산", [18])
AppendStation("장기", [18])
AppendStation("운양", [18])
AppendStation("걸포북변", [18])
AppendStation("사우", [18])
AppendStation("풍무", [18])
AppendStation("고촌", [18])

#신림선
AppendStation("서울지방병무청", [19])
AppendStation("보라매공원", [19])
AppendStation("보라매병원", [19])
AppendStation("당곡", [19])
AppendStation("서원", [19])
AppendStation("서울대벤처타운", [19])
AppendStation("관악산", [19])

#경춘선
AppendStation("갈매", [20])
AppendStation("별내", [20])
AppendStation("퇴계원", [20])
AppendStation("사릉", [20])
AppendStation("금곡", [20])
AppendStation("평내호평", [20])
AppendStation("천마산", [20])
AppendStation("마석", [20])
AppendStation("대성리", [20])
AppendStation("청평", [20])
AppendStation("상천", [20])
AppendStation("가평", [20])
AppendStation("굴봉산", [20])
AppendStation("백양리", [20])
AppendStation("강촌", [20])
AppendStation("김유정", [20])
AppendStation("남춘천", [20])
AppendStation("춘천", [20])

#경강선
AppendStation("성남", [21, 23])
AppendStation("삼동", [21])
AppendStation("경기광주", [21])
AppendStation("초월", [21])
AppendStation("곤지암", [21])
AppendStation("신둔도예촌", [21])
AppendStation("이천", [21])
AppendStation("부발", [21])
AppendStation("세종대왕릉", [21])
AppendStation("여주", [21])

#서해선
AppendStation("원종", [22])
AppendStation("소새울", [22])
AppendStation("시흥대야", [22])
AppendStation("신천", [22])
AppendStation("신현", [22])
AppendStation("시흥시청", [22])
AppendStation("시흥능곡", [22])
AppendStation("달미", [22])
AppendStation("선부", [22])
AppendStation("원곡", [22])
AppendStation("원시", [22])

#GTX-A
#AppendStation("GTX운정", [23]) # 미개통
#AppendStation("킨텍스", [23]) # 미개통
#AppendStation("창릉", [23]) # 미개통
AppendStation("동탄", [23])

# %% [markdown]
# ### 3. Main Code

# %%
def initilize():
    for i in range(len(All_Stations)):
        All_Stations[i][2]=0

# %%
def Judgement(tmpName="", currentLineNo=-1):
    tmpChangeLine=-1
    for i in range(len(All_Stations)):
        if All_Stations[i][0]==tmpName:
            if currentLineNo in All_Stations[i][1]:
                if All_Stations[i][2]==0: #Succeed
                    All_Stations[i][2]=1 #Change to Used
                    print("성공하였습니다")
                    if len(All_Stations[i][1]) > 1: #환승역
                        try:
                            tmpChangeLine=int(input("환승하시겠습니까? 1-예 0-아니오 : "))
                        except:
                            #잘못된 응답으로 탈락
                            return [0, currentLineNo]
                        
                        if tmpChangeLine==1:
                            print("** 호선 정보 **")
                            print("1 : 서울 1호선, 2 : 서울 2호선, 3 : 서울 3호선, 4 : 서울 4호선, 5 : 서울 5호선, 6 : 서울 6호선, 7 : 서울 7호선, 8 : 서울 8호선,")
                            print("9 : 서울 9호선, 10 : 인천 1호선, 11 : 인천 2호선, 12 : 공항철도, 13 : 경의.중앙선, 14 : 수인.분당선, 15 : 우이신설선, 16 : 신분당선,")
                            print("17 : 에버라인, 18 : 의정부경전철, 19 : 김포골드라인, 20 : 신림선, 21 : 경춘선, 22 : 경강선, 23 : 서해선, 24 : GTX-A")
                            tmpChangeLine=-1
                            try:
                                tmpChangeLine=int(input("어떤 호선으로 환승할까요? : "))
                                tmpChangeLine -= 1
                            except:
                                #잘못된 응답으로 탈락
                                return [0, currentLineNo]
                            
                            if tmpChangeLine in All_Stations[i][1] and tmpChangeLine != currentLineNo:
                                #환승 성공
                                return [1, tmpChangeLine]
                            else:
                                #잘못된 응답으로 탈락
                                return [0, currentLineNo]
                        elif tmpChangeLine==0:
                            #환승 안함
                            return [1, currentLineNo]
                        else:
                            #잘못된 응답으로 탈락
                            return [0, currentLineNo]
                    else:
                        #환승역 아님
                        return [1, currentLineNo]
                else:
                    #print("중복")
                    continue
            else:
                #print("해당 노선 역이 아님")
                continue
        else:
            #print("등록되지 않은 역") # 다른 역 검색시에도 등장함
            continue
        
    return [0, currentLineNo]

# %% [markdown]
# ### 4. Play the Game

# %%
import numpy as np

initilize()
currentLineNo=np.random.randint(len(Lines))

isSucceed=1
while isSucceed == 1:
    print("현재 노선 : ", Lines[currentLineNo])
    tmpName=input("역을 입력하세요 : ")
    [isSucceed, currentLineNo]=Judgement(tmpName, currentLineNo)

print("실패하셨습니다")
